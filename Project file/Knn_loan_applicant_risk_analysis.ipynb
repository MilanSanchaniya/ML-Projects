# %% [markdown]
# # Questions

# %%
             Part-1: Data Exploration and Pre-processing

1) load the given dataset 
2) Check for the null values 
3) Get basic information from data 
4) Describe the dataset 
5) Display scatterplot between age & Total work Experience 
6) Display box plot for age 
7) Display box plot for Cibil score 
8) Create target and features data where target is Total bounces past 12 months

               Part-2: Working with Model 

1) Split data into training and testing sets 
2) Create a KNN classifier between Features and target data
3) Display the test score 
4) Display the training score 
5) Print the accuracy score 
6) Try 1 to 14 k values for classifier 
7) Display training and testing score for all the 1 to 14 k values

# %% [markdown]
# # 1) load the given dataset

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
cd C:\Users\dell\OneDrive\Desktop\Finger Tips\Machine learning\Projects\Projects datafile
# Out:
# C:\Users\dell\OneDrive\Desktop\Finger Tips\Machine learning\Projects\Projects datafile

# %%
data=pd.read_excel("ML Project KNN Loan Applicant Credit Risk Analysis.xlsx")

# %% [markdown]
# # 2) Check for the null values

# %%
data.isnull().sum()
# Out:
# Age                           0
# Total Work Experience         0
# Number of years in city       0
# Cost to Request Ratio         0
# Cibil score                   0
# Overdrafts past12months       0
# Total bounces past12months    0
# dtype: int64

# %%
data.drop_duplicates(ignore_index=True,inplace=True)

# %% [markdown]
# # 3) Get basic information from data

# %%
data.info()

# %% [markdown]
# # 4) Describe the dataset

# %%
data.describe()

# %% [markdown]
# # 5) Display scatterplot between age & Total work Experience

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data["Age"],data["Total Work Experience"])

# %% [markdown]
# # 6) Display box plot for age

# %%
plt.boxplot(data["Age"])

# %% [markdown]
# # 7) Display box plot for Cibil score

# %%
plt.boxplot(data["Cibil score"])

# %% [markdown]
# # 8) Create target and features data where target is Total bounces past 12 months

# %%
x = data.drop("Total bounces past12months",axis = 1)
y = data["Total bounces past12months"]

# %% [markdown]
# # 1) Split data into training and testing sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # 2) Create a KNN classifier between Features and target data

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# # 3) Display the test score

# %%
model.score(x_test,y_test)
# Out:
# 0.6375278396436526

# %% [markdown]
# # 4) Display the training score

# %%
model.score(x_train,y_train)
# Out:
# 0.6785018100807575

# %% [markdown]
# # 5) Print the accuracy score

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
model.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
yp=model.predict(x_test)

# %%
accuracy_score(y_test,yp)
# Out:
# 0.6375278396436526

# %% [markdown]
# # 6) Try 1 to 14 k values for classifier
# # 7) Display training and testing score for all the 1 to 14 k values

# %%
accuracie = []
for i in range(1, 15):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, y_train)
    
    yp = knn.predict(x_test)
    acc = accuracy_score(y_test, yp)
    
    accuracie.append(acc)
    print(f"k = {i}, Accuracy = {acc}")
# Out:
# k = 1, Accuracy = 0.5489977728285078
# k = 2, Accuracy = 0.6314031180400891
# k = 3, Accuracy = 0.623608017817372
# k = 4, Accuracy = 0.6341870824053452
# k = 5, Accuracy = 0.6375278396436526
# k = 6, Accuracy = 0.6358574610244989
# k = 7, Accuracy = 0.6397550111358574
# k = 8, Accuracy = 0.6469933184855234
# k = 9, Accuracy = 0.6464365256124721
# k = 10, Accuracy = 0.6475501113585747
# k = 11, Accuracy = 0.6464365256124721
# k = 12, Accuracy = 0.6481069042316259
# k = 13, Accuracy = 0.6503340757238307
# k = 14, Accuracy = 0.6520044543429844
